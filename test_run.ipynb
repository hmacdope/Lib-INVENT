# %%
from running_modes.configurations import ScaffoldDecoratingConfiguration
from running_modes.scaffold_decorating.scaffold_decoration import ScaffoldDecorator
import logging
import mols2grid

# %% [markdown]
# # Running libinvent
#
# Due to the shonky way the code is build you will need to run this from root dir

# %%
s = ScaffoldDecoratingConfiguration(model_path="./trained_models/reaction_based.model", input_scaffold_path="./test.smi", logging_path="./output", output_path="./generate_out.csv")

# %%
sd = ScaffoldDecorator(s, None)

# %%
df = sd.run()
# Out:
# Invalid decorations: C(=O)(c1ccccc1*)* for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: *C1c2c(C(=O)*)cccc2CCC1 for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: C(=O)(c1ccc(*)cc1)* for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: c1(C*)ccc(C(=O)*)cc1 for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: c1(C*)cc(C(=O)*)ccc1 for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: O=C(C*)* for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: c1(*)ccc(C(=O)*)cc1 for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: C(c1cc(*)ccc1)(*)=O for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# Invalid decorations: C(c1cccc(*)c1)(*)=O for scaffold [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# ...

# %%
df
# Out:
#                                                  SMILES
# 0     C(Cc1ccccc1)N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)...  \
# 1      CC(=O)N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# 2           CN1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O
# 3     c1(CN2CC(C(=O)Nc3cncc4ccccc34)c3cc(Cl)ccc3C2=O...
# 4     C(=O)(c1ccccc1)N1CC(C(=O)Nc2cncc3ccccc23)c2cc(...
# ...                                                 ...
# 1370  c1(Cl)c(C(=O)N2CC(C(=O)Nc3cncc4ccccc34)c3cc(Cl...
# 1371  c1(OC)cc(C(=O)N2CC(C(=O)Nc3cncc4ccccc34)c3cc(C...
# 1372  c1cc(N2CC(C(=O)Nc3cncc4ccccc34)c3cc(Cl)ccc3C2=...
# 1373  c1(N2CC(C(=O)Nc3cncc4ccccc34)c3cc(Cl)ccc3C2=O)...
# 1374  C(c1cccc2ccccc12)N1CC(C(=O)Nc2cncc3ccccc23)c2c...
#
#                                            Scaffold               Decorations
# 0     [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O               *CCc1ccccc1  \
# 1     [*]N1CC(C(=O)Nc2cncc3ccccc23)c2cc(Cl)ccc2C1=O                   CC(=O)*
# ...

# %%
import pandas as pd
from rdkit import Chem

# %%
scaf = sd._samples[0].scaffold

# %%
m = Chem.MolFromSmiles(scaf)

# %%
mols2grid.display([m])
# Out:
# MolGridWidget()
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
#
# sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# ...

# %%
mols2grid.display(df, smiles_col="SMILES")
# Out:
# MolGridWidget()
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
#
# sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# ...

# %%
mols2grid.display(df, smiles_col="Decorations")
# Out:
# MolGridWidget()
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
#
# sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# ...
